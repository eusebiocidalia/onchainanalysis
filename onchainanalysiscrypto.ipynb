# %% [markdown]
# On chain Analysis for Top 20 Cryptocurrency

# %%
pip install streamlit gspread oauth2client pandas
# Out:
# Requirement already satisfied: streamlit in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.18.1)
# Collecting gspread
#   Downloading gspread-6.2.1-py3-none-any.whl (59 kB)
#      ---------------------------------------- 0.0/60.0 kB ? eta -:--:--
#      ---------------------------------------- 60.0/60.0 kB ? eta 0:00:00
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ---------------------------------------- 0.0/98.2 kB ? eta -:--:--
#      ---------------------------------------- 98.2/98.2 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.3.0)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (1.5)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: validators>=0.2 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (4.2)
# Requirement already satisfied: packaging>=14.1 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (23.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (8.7.0)
# Requirement already satisfied: semver in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (2.9.0.post0)
# Requirement already satisfied: pympler>=0.9 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (6.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (13.3.1)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (3.19.6)
# Requirement already satisfied: watchdog in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (2.2.1)
# Requirement already satisfied: numpy in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: click>=7.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: requests>=2.4 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: cachetools>=4.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: toml in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (3.1.31)
# Requirement already satisfied: altair>=3.2.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gspread) (0.4.6)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gspread) (2.16.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from oauth2client) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from oauth2client) (4.9)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from oauth2client) (0.4.8)
# Collecting httplib2>=0.9.1
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#      ---------------------------------------- 96.9/96.9 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.6.1 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2022.7)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from altair>=3.2.0->streamlit) (4.17.3)
# Requirement already satisfied: jinja2 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from altair>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: entrypoints in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from altair>=3.2.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from click>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gitpython!=3.1.19->streamlit) (4.0.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httplib2>=0.9.1->oauth2client) (3.0.9)
# Requirement already satisfied: zipp>=3.20 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from importlib-metadata>=1.4->streamlit) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.4->streamlit) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.4->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.4->streamlit) (2025.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.4->streamlit) (3.4)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from rich>=10.11.0->streamlit) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from rich>=10.11.0->streamlit) (2.1.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (25.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich>=10.11.0->streamlit) (0.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jlapa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Installing collected packages: httplib2, oauth2client, gspread
# Successfully installed gspread-6.2.1 httplib2-0.22.0 oauth2client-4.1.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\jlapa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import streamlit as st
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Title
st.title("🔗 On-Chain Metrics Dashboard")

# Instructions
st.markdown("""
This dashboard helps you manually enter and assess on-chain metrics for your favorite cryptocurrencies. 
Color-coded flags will help guide you on potential signals (bullish, neutral, bearish).
""")

# Load initial checklist (can be expanded or replaced with your own Google Sheet integration)
coins = [
    "Bitcoin", "Ethereum", "Solana", "Shiba Inu", "Avalanche",
    "Cardano", "Polkadot", "Chainlink", "Uniswap", "Litecoin",
    "XRP", "Stellar", "Dogecoin", "Wrapped Bitcoin", "Tron",
    "Internet Computer", "Polygon", "Binance Coin", "USD Coin", "Pepe",
    "CRO", "Jupiter", "KAIA"
]

metrics = {
    "Market Capitalization": ("High = Popular, Risk of Overvaluation", "Low = Potential Growth Area"),
    "Realized Capitalization": ("Tracks Actual Value Paid", "Used in MVRV, not direct signal"),
    "Active Addresses": ("More = Usage, Bullish", "Drop = Lack of Interest"),
    "Addresses Holding > X": ("Rise = Confidence", "Drop = Weak Hands"),
    "Transaction Volume": ("Spike = Shift in Sentiment", "Low = Disinterest"),
    "Hash Rate": ("Up = Network Secure", "Down = Risk of Attack (PoW only)"),
    "Exchange Flows": ("Inflow = Bearish", "Outflow = Bullish"),
    "Net Unrealized Profit/Loss (NUPL)": (">0.75 = Overheated", "<0.5 = Safer Zone"),
    "Long/Short-Term On-chain Cost Basis": ("Below Price = Bullish", "Above = Risk"),
    "SOPR": (">1 = Profit Taking", "<1 = Capitulation"),
    "MVRV": (">3 = Overvalued", "<1 = Undervalued"),
    "Long-Term Holder MVRV": ("High = Distribution Phase", "Low = Accumulation"),
    "Short-Term Holder MVRV": ("High = Caution", "Low = Opportunity"),
    "MVRV Z-Score": (">7 = Top Zone", "<0 = Undervalued"),
    "Spot Volume": ("Spike = Volatility Ahead", "Flat = Calm Market"),
    "Spot Volume Delta": ("Spike = Momentum Change", "Drop = Pause"),
    "Percent Balance on Exchanges": ("High = Sell Pressure", "Low = Long-Term Holding"),
    "Net Transfer Volume": ("Out = Bullish", "In = Bearish")
}

# Create editable table
data = []
for coin in coins:
    row = {"Coin": coin}
    for metric in metrics:
        row[metric] = ""
    data.append(row)

df = pd.DataFrame(data)
edited_df = st.data_editor(df, num_rows="dynamic")

# Show guidance
st.subheader("🧠 Metric Interpretation Guide")
for metric, (high_signal, low_signal) in metrics.items():
    st.markdown(f"**{metric}**: {high_signal} | {low_signal}")

# Summary insights
st.subheader("📊 Summary Insights")
for i, row in edited_df.iterrows():
    coin = row["Coin"]
    insights = []

    try:
        if row["MVRV"] != "" and float(row["MVRV"]) > 3:
            insights.append("⚠️ MVRV is high — overvaluation risk")
        elif row["MVRV"] != "" and float(row["MVRV"]) < 1:
            insights.append("🟢 MVRV is low — may be undervalued")

        if row["SOPR"] != "" and float(row["SOPR"]) > 1.1:
            insights.append("🔺 SOPR high — taking profits")
        elif row["SOPR"] != "" and float(row["SOPR"]) < 1:
            insights.append("🔻 SOPR low — potential bottoming")

        if row["Net Unrealized Profit/Loss (NUPL)"] != "" and float(row["Net Unrealized Profit/Loss (NUPL)"]) > 0.75:
            insights.append("🔥 NUPL is high — market may be overheated")
        elif row["Net Unrealized Profit/Loss (NUPL)"] != "" and float(row["Net Unrealized Profit/Loss (NUPL)"]) < 0.5:
            insights.append("🟢 NUPL is moderate — safer zone")

    except ValueError:
        continue

    if insights:
        st.markdown(f"**{coin}**")
        for ins in insights:
            st.write(ins)

# Download section
st.subheader("📥 Download Your Data")
st.download_button(
    label="Download CSV",
    data=edited_df.to_csv(index=False).encode('utf-8'),
    file_name="onchain_metrics_snapshot.csv",
    mime="text/csv"
)

# Google Sheets Upload (requires credentials.json)
st.subheader("📤 Save to Google Sheets")
try:
    credentials = ServiceAccountCredentials.from_json_keyfile_name(
        "credentials.json",
        ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
    )
    client = gspread.authorize(credentials)
    sheet = client.create("OnChain_Metrics_Snapshot")
    worksheet = sheet.get_worksheet(0)
    worksheet.update([edited_df.columns.values.tolist()] + edited_df.values.tolist())
    st.success("Successfully uploaded to Google Sheets!")
except Exception as e:
    st.warning("Google Sheets upload failed. Make sure 'credentials.json' exists and has access.")
    st.text(str(e))
# Out:
# 2025-07-23 10:49:15.843
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\jlapa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 54
#      51     data.append(row)
#      53 df = pd.DataFrame(data)
# ---> 54 edited_df = st.data_editor(df, num_rows="dynamic")
#      56 # Show guidance
#      57 st.subheader("🧠 Metric Interpretation Guide")
#
# AttributeError: module 'streamlit' has no attribute 'data_editor'
